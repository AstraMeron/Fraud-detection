# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
# Load cleaned datasets
fraud_df = pd.read_csv("../data/processed/fraud_data_preprocessed.csv")
creditcard_df = pd.read_csv("../data/raw/creditcard.csv")

print("Fraud data shape:", fraud_df.shape)
print("Credit card data shape:", creditcard_df.shape)
# Out:
# Fraud data shape: (273922, 196)
# Credit card data shape: (284807, 31)

# %%
# Save processed datasets
fraud_df.to_csv("../data/processed/fraud_data_final.csv", index=False)
creditcard_df.to_csv("../data/processed/creditcard_processed.csv", index=False)

print("Saved processed datasets to data/processed/")
# Out:
# Saved processed datasets to data/processed/
